# %%
pip install python-Levenshtein
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-Levenshtein
#   Downloading python_levenshtein-0.27.1-py3-none-any.whl (9.4 kB)
# Collecting Levenshtein==0.27.1
#   Downloading levenshtein-0.27.1-cp39-cp39-win_amd64.whl (100 kB)
#      ------------------------------------ 100.0/100.0 kB 191.5 kB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.9.0
#   Downloading rapidfuzz-3.13.0-cp39-cp39-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, Levenshtein, python-Levenshtein
# Successfully installed Levenshtein-0.27.1 python-Levenshtein-0.27.1 rapidfuzz-3.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from fuzzywuzzy import fuzz
import jieba
import os
import re

# %%
# Define root directory
root_dir = r"D:/铁书宁/2025 HKU predoc/RA task1_20250405"

df_path = os.path.join(root_dir, "ar-sale-buyer-match_forShuning.csv")
df = pd.read_csv(df_path)

# %% [markdown]
# ### Step 1: City match for the AR buyer and customer.

# %%
# Import region dataset
city_path = os.path.join(root_dir, "China-City-List-latest.csv")
city_df = pd.read_csv(city_path, encoding = 'utf-8', header = 1)

# Keep city names
city_df = city_df[['Adm1_Name_ZH','Adm2_Name_ZH']]
city_df = city_df.drop_duplicates()

# Delele the word "省" and "市"
city_df['Adm1_Name_ZH'] = city_df['Adm1_Name_ZH'].str[:-1]
city_df['Adm2_Name_ZH'] = city_df['Adm2_Name_ZH'].str[:-1]

# Generate a region list
regions = pd.concat([city_df['Adm1_Name_ZH'], city_df['Adm2_Name_ZH']])
regions = list(regions.drop_duplicates())

# %%
# Define a region extract function
def extract_region(name):
    for region in regions:
        if region in name:
            return region
    return None

df['ar_buyer_region'] = df['ar_buyer_standard'].astype(str).apply(extract_region)
df['cus_region'] = df['cus_name_standard'].astype(str).apply(extract_region)

# %%
# City match for ar_buyer and cus_name, also keep the N.A.
df_citymatch = df[
    (df['ar_buyer_region'] == df['cus_region']) |
    (df['ar_buyer_region'].isna() & df['cus_region'].isna())
]

# %%
df_citymatch.head(10)
# Out:
#      wind_code sec_name ar_by_buyer_name ar_buyer_standard  ar_buyer_subid  \
# 77   000004.SZ     国华网安           内蒙古公安厅            内蒙古公安厅               6
# 107  000004.SZ     国华网安              周文亮               周文亮               8
# 121  000004.SZ     国华网安     四川科伦医药贸易有限公司      四川科伦医药贸易有限公司               9
# 136  000004.SZ     国华网安   国药控股四川医药股份有限公司    国药控股四川医药股份有限公司              10
# 152  000004.SZ     国华网安       宁夏耀康医药有限公司        宁夏耀康医药有限公司              11
# 183  000004.SZ     国华网安     山东瑞康医药股份有限公司      山东瑞康医药股份有限公司              13
# 198  000004.SZ     国华网安       山东豪诺医药有限公司        山东豪诺医药有限公司              14
# 302  000004.SZ     国华网安              杜秀珍               杜秀珍              21
# 317  000004.SZ     国华网安           杨秀兰,丁亮            杨秀兰,丁亮              22
# 351  000004.SZ     国华网安     河北龙海新药经营有限公司      河北龙海新药经营有限公司              24
#
#          cus_name cus_name_standard  cus_name_subid ar_buyer_region cus_region
# 77    国药乐仁堂医药有限公司       国药乐仁堂医药有限公司               3            None       None
# 107   国药乐仁堂医药有限公司       国药乐仁堂医药有限公司               3            None       None
# 121  四川源亨众生医药有限公司      四川源亨众生医药有限公司               2              四川         四川
# 136  四川源亨众生医药有限公司      四川源亨众生医药有限公司               2              四川         四川
# 152   国药乐仁堂医药有限公司       国药乐仁堂医药有限公司               3            None       None
# 183    山东众智医药有限公司        山东众智医药有限公司               4              山东         山东
# 198    山东众智医药有限公司        山东众智医药有限公司               4              山东         山东
# 302   国药乐仁堂医药有限公司       国药乐仁堂医药有限公司               3            None       None
# 317   国药乐仁堂医药有限公司       国药乐仁堂医药有限公司               3            None       None
# 351    河北启源医药有限公司        河北启源医药有限公司               7              河北         河北

# %% [markdown]
# ### Step 2: Use Jieba to seperate the string to words.

# %%
# Use jieba to seperate the words.
df_citymatch = df_citymatch.copy()
df_citymatch['ar_buyer_seg'] = df_citymatch['ar_buyer_standard'].astype(str).apply(lambda x: jieba.lcut(x))
df_citymatch['cus_name_seg'] = df_citymatch['cus_name_standard'].astype(str).apply(lambda x: jieba.lcut(x))

# %%
df_citymatch = df_citymatch.copy()
df_citymatch['cus_name_seg_str'] = df_citymatch['cus_name_seg'].apply(lambda x: ' '.join(x))
df_citymatch['ar_buyer_seg_str'] = df_citymatch['ar_buyer_seg'].apply(lambda x: ' '.join(x))

# %% [markdown]
# #### Jieba just for Chinese names, so for English names, we normalize the text by removing spaces and punctuation.

# %%
# Determine if it is English name
def is_english(text):
    return bool(re.match(r'^[\x00-\x7F]+$', text))

# Retain letters and numbers, remove special symbols such as spaces, punctuation, etc., and convert to lower case
def clean_english_text(text):
    return re.sub(r'[^a-zA-Z0-9]', '', text).lower()

# %%
df_citymatch['ar_buyer_seg_str'] = df_citymatch['ar_buyer_seg_str'].astype(str).apply(
    lambda x: clean_english_text(x) if is_english(x) else x
)

df_citymatch['cus_name_seg_str'] = df_citymatch['cus_name_seg_str'].astype(str).apply(
    lambda x: clean_english_text(x) if is_english(x) else x
)

# %% [markdown]
# ### Step 3: Compute fuzzy match score

# %%
df_fuzzymatch = df_citymatch.iloc[:,:]

# Fuzzy match function
def fuzzy_match(name1, name2):
    return fuzz.token_sort_ratio(name1, name2)

# Apply fuzzy matching to your columns
df_fuzzymatch['match_score'] = df_fuzzymatch.apply(lambda row: fuzzy_match(row['cus_name_seg_str'], row['ar_buyer_seg_str']), axis=1)

# %%
output_path1 = os.path.join(root_dir, "df_fuzzymatch_v2.csv")
df_fuzzymatch.to_csv(output_path1, encoding = 'utf-8-sig')

# %% [markdown]
# #### (1) Choose 85 as a cutoff score

# %%
df_fuzzymatch85 = df_fuzzymatch[df_fuzzymatch['match_score'] >= 85]
df_fuzzymatch85.head(10)
# Out:
#      wind_code sec_name                         ar_by_buyer_name  \
# 430  000004.SZ     国华网安                             福建乐游网络科技有限公司
# 432  000004.SZ     国华网安                             福建乐游网络科技有限公司
# 446  000004.SZ     国华网安                               福建众邦药业有限公司
# 460  000004.SZ     国华网安                             福建摩格网络科技有限公司
# 462  000004.SZ     国华网安                             福建摩格网络科技有限公司
# 551  000006.SZ     深振业A                               天虹商场股份有限公司
# 599  000006.SZ     深振业A                       深圳市前海同创汇产业运营管理有限公司
# 619  000006.SZ     深振业A                              深圳市南山区建筑工务署
# 797  000007.SZ      全新好  MAPLE PACKING INDUSTRIAL (H.K.) LIMITED
# 814  000007.SZ      全新好      MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
#
#                            ar_buyer_standard  ar_buyer_subid  \
# 430                             福建乐游网络科技有限公司              29
# 432                             福建乐游网络科技有限公司              29
# 446                               福建众邦药业有限公司              30
# 460                             福建摩格网络科技有限公司              31
# 462                             福建摩格网络科技有限公司              31
# 551                               天虹商场股份有限公司               2
# 599                       深圳市前海同创汇产业运营管理有限公司               7
# 619                              深圳市南山区建筑工务署               9
# 797  MAPLE PACKING INDUSTRIAL (H.K.) LIMITED               5
# 814      MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED               6
#
#                                 cus_name                    cus_name_standard  \
# 430                         福建乐游网络科技有限公司                         福建乐游网络科技有限公司
# 432                         福建摩格网络科技有限公司                         福建摩格网络科技有限公司
# 446                           福建众邦药业有限公司                           福建众邦药业有限公司
# 460                         福建乐游网络科技有限公司                         福建乐游网络科技有限公司
# 462                         福建摩格网络科技有限公司                         福建摩格网络科技有限公司
# 551                           天虹商场股份有限公司                           天虹商场股份有限公司
# 599                   深圳市前海同创汇产业运营管理有限公司                   深圳市前海同创汇产业运营管理有限公司
# 619                          深圳市南山区建筑工务署                          深圳市南山区建筑工务署
# 797  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
# 814  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
#
#      cus_name_subid ar_buyer_region cus_region  \
# 430              11              福建         福建
# 432              13              福建         福建
# 446              12              福建         福建
# 460              11              福建         福建
# 462              13              福建         福建
# 551               3            None       None
# 599               6              深圳         深圳
# 619               8              深圳         深圳
# 797               1            None       None
# 814               1            None       None
#
#                                           ar_buyer_seg  \
# 430                               [福建, 乐游, 网络科技, 有限公司]
# 432                               [福建, 乐游, 网络科技, 有限公司]
# 446                                 [福建, 众邦, 药业, 有限公司]
# 460                               [福建, 摩格, 网络科技, 有限公司]
# 462                               [福建, 摩格, 网络科技, 有限公司]
# 551                                 [天虹, 商场, 股份, 有限公司]
# 599                   [深圳市, 前海同, 创汇, 产业, 运营, 管理, 有限公司]
# 619                              [深圳市, 南山区, 建筑, 工务, 署]
# 797  [MAPLE,  , PACKING,  , INDUSTRIAL,  , (, H, .,...
# 814  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
#
#                                           cus_name_seg  \
# 430                               [福建, 乐游, 网络科技, 有限公司]
# 432                               [福建, 摩格, 网络科技, 有限公司]
# 446                                 [福建, 众邦, 药业, 有限公司]
# 460                               [福建, 乐游, 网络科技, 有限公司]
# 462                               [福建, 摩格, 网络科技, 有限公司]
# 551                                 [天虹, 商场, 股份, 有限公司]
# 599                   [深圳市, 前海同, 创汇, 产业, 运营, 管理, 有限公司]
# 619                              [深圳市, 南山区, 建筑, 工务, 署]
# 797  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
# 814  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
#
#                     cus_name_seg_str                 ar_buyer_seg_str  \
# 430                  福建 乐游 网络科技 有限公司                  福建 乐游 网络科技 有限公司
# 432                  福建 摩格 网络科技 有限公司                  福建 乐游 网络科技 有限公司
# 446                    福建 众邦 药业 有限公司                    福建 众邦 药业 有限公司
# 460                  福建 乐游 网络科技 有限公司                  福建 摩格 网络科技 有限公司
# 462                  福建 摩格 网络科技 有限公司                  福建 摩格 网络科技 有限公司
# 551                    天虹 商场 股份 有限公司                    天虹 商场 股份 有限公司
# 599         深圳市 前海同 创汇 产业 运营 管理 有限公司         深圳市 前海同 创汇 产业 运营 管理 有限公司
# 619                  深圳市 南山区 建筑 工务 署                  深圳市 南山区 建筑 工务 署
# 797  maplepackingindustrialhklimited  maplepackingindustrialhklimited
# 814  maplepackingindustrialhklimited  maplepackingindustrialhklimited
#
#      match_score
# 430          100
# 432           87
# 446          100
# 460           87
# 462          100
# 551          100
# 599          100
# 619          100
# 797          100
# 814          100

# %%
output_path2 = os.path.join(root_dir, "df_fuzzymatch85_v2.csv")
df_fuzzymatch85.to_csv(output_path2, encoding = 'utf-8-sig')

# %% [markdown]
# #### (1) Choose 90 as a cutoff score

# %%
df_fuzzymatch90 = df_fuzzymatch[df_fuzzymatch['match_score'] >= 90]
df_fuzzymatch90.head(10)
# Out:
#      wind_code sec_name                         ar_by_buyer_name  \
# 430  000004.SZ     国华网安                             福建乐游网络科技有限公司
# 446  000004.SZ     国华网安                               福建众邦药业有限公司
# 462  000004.SZ     国华网安                             福建摩格网络科技有限公司
# 551  000006.SZ     深振业A                               天虹商场股份有限公司
# 599  000006.SZ     深振业A                       深圳市前海同创汇产业运营管理有限公司
# 619  000006.SZ     深振业A                              深圳市南山区建筑工务署
# 797  000007.SZ      全新好  MAPLE PACKING INDUSTRIAL (H.K.) LIMITED
# 814  000007.SZ      全新好      MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
# 831  000007.SZ      全新好            MAPLEPACKINGINDUSTRIALLIMITED
# 900  000007.SZ      全新好            WANDE INDUSTRIAL (HK) LIMITED
#
#                            ar_buyer_standard  ar_buyer_subid  \
# 430                             福建乐游网络科技有限公司              29
# 446                               福建众邦药业有限公司              30
# 462                             福建摩格网络科技有限公司              31
# 551                               天虹商场股份有限公司               2
# 599                       深圳市前海同创汇产业运营管理有限公司               7
# 619                              深圳市南山区建筑工务署               9
# 797  MAPLE PACKING INDUSTRIAL (H.K.) LIMITED               5
# 814      MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED               6
# 831            MAPLEPACKINGINDUSTRIALLIMITED               7
# 900            WANDE INDUSTRIAL (HK) LIMITED              11
#
#                                 cus_name                    cus_name_standard  \
# 430                         福建乐游网络科技有限公司                         福建乐游网络科技有限公司
# 446                           福建众邦药业有限公司                           福建众邦药业有限公司
# 462                         福建摩格网络科技有限公司                         福建摩格网络科技有限公司
# 551                           天虹商场股份有限公司                           天虹商场股份有限公司
# 599                   深圳市前海同创汇产业运营管理有限公司                   深圳市前海同创汇产业运营管理有限公司
# 619                          深圳市南山区建筑工务署                          深圳市南山区建筑工务署
# 797  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
# 814  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
# 831  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED  MAPLEPACKINGINDUSTRIAL(H.K.)LIMITED
# 900           WANDEINDUSTRIAL(HK)LIMITED           WANDEINDUSTRIAL(HK)LIMITED
#
#      cus_name_subid ar_buyer_region cus_region  \
# 430              11              福建         福建
# 446              12              福建         福建
# 462              13              福建         福建
# 551               3            None       None
# 599               6              深圳         深圳
# 619               8              深圳         深圳
# 797               1            None       None
# 814               1            None       None
# 831               1            None       None
# 900               2            None       None
#
#                                           ar_buyer_seg  \
# 430                               [福建, 乐游, 网络科技, 有限公司]
# 446                                 [福建, 众邦, 药业, 有限公司]
# 462                               [福建, 摩格, 网络科技, 有限公司]
# 551                                 [天虹, 商场, 股份, 有限公司]
# 599                   [深圳市, 前海同, 创汇, 产业, 运营, 管理, 有限公司]
# 619                              [深圳市, 南山区, 建筑, 工务, 署]
# 797  [MAPLE,  , PACKING,  , INDUSTRIAL,  , (, H, .,...
# 814  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
# 831                    [MAPLEPACKINGINDUSTRIALLIMITED]
# 900    [WANDE,  , INDUSTRIAL,  , (, HK, ),  , LIMITED]
#
#                                           cus_name_seg  \
# 430                               [福建, 乐游, 网络科技, 有限公司]
# 446                                 [福建, 众邦, 药业, 有限公司]
# 462                               [福建, 摩格, 网络科技, 有限公司]
# 551                                 [天虹, 商场, 股份, 有限公司]
# 599                   [深圳市, 前海同, 创汇, 产业, 运营, 管理, 有限公司]
# 619                              [深圳市, 南山区, 建筑, 工务, 署]
# 797  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
# 814  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
# 831  [MAPLEPACKINGINDUSTRIAL, (, H, ., K, ., ), LIM...
# 900               [WANDEINDUSTRIAL, (, HK, ), LIMITED]
#
#                     cus_name_seg_str                 ar_buyer_seg_str  \
# 430                  福建 乐游 网络科技 有限公司                  福建 乐游 网络科技 有限公司
# 446                    福建 众邦 药业 有限公司                    福建 众邦 药业 有限公司
# 462                  福建 摩格 网络科技 有限公司                  福建 摩格 网络科技 有限公司
# 551                    天虹 商场 股份 有限公司                    天虹 商场 股份 有限公司
# 599         深圳市 前海同 创汇 产业 运营 管理 有限公司         深圳市 前海同 创汇 产业 运营 管理 有限公司
# 619                  深圳市 南山区 建筑 工务 署                  深圳市 南山区 建筑 工务 署
# 797  maplepackingindustrialhklimited  maplepackingindustrialhklimited
# 814  maplepackingindustrialhklimited  maplepackingindustrialhklimited
# 831  maplepackingindustrialhklimited    maplepackingindustriallimited
# 900         wandeindustrialhklimited         wandeindustrialhklimited
#
#      match_score
# 430          100
# 446          100
# 462          100
# 551          100
# 599          100
# 619          100
# 797          100
# 814          100
# 831           97
# 900          100

# %%
output_path3 = os.path.join(root_dir, "df_fuzzymatch90_v2.csv")
df_fuzzymatch90.to_csv(output_path3, encoding = 'utf-8-sig')
